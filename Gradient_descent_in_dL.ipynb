# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
import keras
from sklearn.datasets import make_moons
from sklearn.model_selection import train_test_split
from keras.layers import Dense
from keras.models import Sequential

# %%
X,y= make_moons(n_samples=250,noise=0.3,random_state=42)      ## making classification dataset using make_moon

# %%
plt.scatter(X[:,0],X[:,1],c=y,s=100)
plt.show()

# %%
## making deep neural ntwork
model = Sequential()

model.add(Dense(10,activation='sigmoid',input_dim=2))
model.add(Dense(10,activation='sigmoid'))
model.add(Dense(10,activation='sigmoid'))
model.add(Dense(10,activation='sigmoid'))
model.add(Dense(10,activation='sigmoid'))
model.add(Dense(10,activation='sigmoid'))
model.add(Dense(10,activation='sigmoid'))
model.add(Dense(10,activation='sigmoid'))
model.add(Dense(10,activation='sigmoid'))
model.add(Dense(10,activation='sigmoid'))
model.add(Dense(10,activation='sigmoid'))
model.add(Dense(10,activation='sigmoid'))
model.add(Dense(10,activation='sigmoid'))
model.add(Dense(10,activation='sigmoid'))
model.add(Dense(1,activation='sigmoid'))
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/core/dense.py:106: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
model.compile(loss='binary_crossentropy',optimizer='adam',metrics=['accuracy'])

# %%
old_weights= model.get_weights()[0]       ## storing the first layer weights in old_weights

# %%
model.get_weights()[0]      ## weights of firesst lkayerm
# Out:
# array([[ 0.6306996 ,  0.44188827, -0.05379421,  0.21337229, -0.15659106,
#          0.04210907, -0.06600147, -0.127154  ,  0.10578775, -0.5134454 ],
#        [ 0.02647072, -0.33636203, -0.31678516,  0.64191777,  0.13467062,
#          0.28541273, -0.18335092, -0.50269085,  0.22969407,  0.41253775]],
#       dtype=float32)

# %%
X_train,X_test,y_train,y_test=train_test_split(X,y,random_state=42,test_size=0.2)

# %%
model.fit(X_train,y_train,epochs=1)
# Out:
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 5s 8ms/step - accuracy: 0.5100 - loss: 0.7811

# %%
new_weights=model.get_weights()[0]      ## storing weights in new_weights

# %%
model.optimizer.get_config()['learning_rate']
# Out:
# 0.0010000000474974513
